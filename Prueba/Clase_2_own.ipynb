# %% [markdown]
# <a href="https://colab.research.google.com/github/carlaalayo/Prueba/blob/main/Prueba/Clase_2_own.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Listas

# %%
# como creamos una lista?
dau_week = ['Lunes', 'Martes', 'Miercoles', 'Jueves', 'Viernes']
print(dau_week)
# Out:
# ['Lunes', 'Martes', 'Miercoles', 'Jueves', 'Viernes']

# %%
print(type(dau_week))
# Out:
# <class 'list'>

# %%
cursos = ["Historia", "Matematicas", "Lengua", "Geografia"]
mi_lista = [10, "PUCP", False, 100.5]

# %%
print(type(cursos))
print(type(mi_lista))
# Out:
# <class 'list'>
# <class 'list'>

# %%
print(len(cursos))
# Out:
# 4

# %%
print(len(mi_lista))
# Out:
# 4

# %%
vacia = []
print(len(vacia))
# Out:
# 0

# %% [markdown]
# #Operaciones

# %%
nueva_lista = cursos + mi_lista
print(nueva_lista)
# Out:
# ['Historia', 'Matematicas', 'Lengua', 'Geografia', 10, 'PUCP', False, 100.5]
